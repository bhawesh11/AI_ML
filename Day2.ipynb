# %% [markdown]
# <a href="https://colab.research.google.com/github/bhawesh11/AI_ML/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

a,b = 5,10
print("Sum :", a+b)

numbers = [1,2,3,4,5]
for n in numbers:
  if n%2 != 0:
    print(n**2)


arr = np.array([1,4,9,16,25])
print("Mean: ",np.mean(arr))
print("Median: ",np.median(arr))
print("Standard Deviation: ",np.std(arr))


data = {
    "Name": ["Amit", "Neha", "Raj", "Simran"],
    "Age": [25, 28, 22, 30],
    "Score": [88, 92, 95, 70]
}

df = pd.DataFrame(data)
display(df)

print(df.describe())
print("Mean score:", df["Score"].mean())
df[df["Score"] > 90]
# Out:
# Sum : 15
# 1
# 9
# 25
# Mean:  11.0
# Median:  9.0
# Standard Deviation:  8.648699324175862
#      Name  Age  Score
# 0    Amit   25     88
# 1    Neha   28     92
# 2     Raj   22     95
# 3  Simran   30     70
#          Age      Score
# count   4.00   4.000000
# mean   26.25  86.250000
# std     3.50  11.206397
# min    22.00  70.000000
# 25%    24.25  83.500000
# 50%    26.50  90.000000
# 75%    28.50  92.750000
# max    30.00  95.000000
# Mean score: 86.25
#    Name  Age  Score
# 1  Neha   28     92
# 2   Raj   22     95
